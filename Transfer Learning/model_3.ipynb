# %%
from ultralytics import YOLO
import torch

# %%
print(torch.cuda.is_available())
# Out:
# True

# %%
model = YOLO("yolov8s-cls.pt")

model.info()
# Out:
# YOLOv8s-cls summary: 56 layers, 6,361,736 parameters, 0 gradients, 13.6 GFLOPs
# (56, 6361736, 0, 13.609779199999998)

# %%
import os
import shutil
from torchvision.datasets import Flowers102

# %%
train_dataset = Flowers102(root='data', split='train', download=True)
val_dataset = Flowers102(root='data', split='val', download=True)
test_dataset = Flowers102(root='data', split='test', download=True)

# %%
base_dir = 'flowers_yolo'

os.makedirs(base_dir, exist_ok=True)
os.makedirs(os.path.join(base_dir, 'train'), exist_ok =True)
os.makedirs(os.path.join(base_dir, 'val'), exist_ok =True)
os.makedirs(os.path.join(base_dir, 'test'), exist_ok=True)

# %% [markdown]
# Copying images to class folders

# %%
def convert_dataset(dataset, split):
    split_dir = os.path.join(base_dir, split)

    for img_path, label in zip(dataset._image_files, dataset._labels):

        label = int(label)

        class_dir = os.path.join(split_dir, str(label))
        os.makedirs(class_dir, exist_ok=True)

        filename = os.path.basename(img_path)
        dest_path = os.path.join(class_dir, filename)

        shutil.copy(img_path, dest_path)

# %%
convert_dataset(train_dataset, 'train')
convert_dataset(val_dataset, 'val')
convert_dataset(test_dataset, 'test')

# %%
len(os.listdir("flowers_yolo/train"))
# Out:
# 102

# %%
print(model.model)
# Out:
# ClassificationModel(
#   (model): Sequential(
#     (0): Conv(
#       (conv): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (1): Conv(
#       (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (2): C2f(
#       (cv1): Conv(
#         (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Conv(
#         (conv): Conv2d(96, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %% [markdown]
# Feature Extraction

# %%
model.train(
    data = 'flowers_yolo',
    epochs = 10,
    imgsz = 224,
    batch =32
)
# Out:
# Ultralytics 8.4.22 🚀 Python-3.12.11 torch-2.8.0+cu128 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
metrics = model.val()

print("Top-1 Accuracy:", metrics.top1)
print("Top-5 Accuracy:", metrics.top5)
# Out:
# Ultralytics 8.4.22 🚀 Python-3.12.11 torch-2.8.0+cu128 CUDA:0 (Tesla T4, 15095MiB)
# train: /teamspace/studios/this_studio/DeepLearningModels/Transfer Learning/flowers_yolo/train... found 1020 images in 102 classes ✅
# val: /teamspace/studios/this_studio/DeepLearningModels/Transfer Learning/flowers_yolo/val... found 1020 images in 102 classes ✅
# test: /teamspace/studios/this_studio/DeepLearningModels/Transfer Learning/flowers_yolo/test... found 6149 images in 102 classes ✅
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1685.4±467.7 MB/s, size: 45.4 KB)
# val: Scanning /teamspace/studios/this_studio/DeepLearningModels/Transfer Learning/flowers_yolo/val... 1020 images, 0 corrupt: 100% ━━━━━━━━━━━━ 1020/1020 388.9Mit/s 0.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 64/64 14.7it/s 4.3s0.1s
#                    all      0.559      0.825
# Speed: 0.2ms preprocess, 0.9ms inference, 0.0ms loss, 0.0ms postprocess per image
# ...

# %% [markdown]
# Learning Curve and Confusion Matrix

# %%
from IPython.display import Image, display

display(Image(filename="runs/classify/train6/results.png"))

# %%
display(Image(filename="runs/classify/train6/confusion_matrix.png"))
